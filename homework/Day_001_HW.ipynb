# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = sum((y-yp)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 249.748
# The Mean absolute error is 12.857

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要? <p>了解影響房價的因素，對房市投資會有幫助</p>
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# <p>資料提供者為 Dean De Cock， 資料集刊於 Journal of Statistics Education Volume 19, Number 3(2011)</p>
# 3. 蒐集而來的資料型態為何
# <p>結構化資料，以表格形式呈現。</p>
# 4. 這組資料想解決的問題如何評估
# <p>Root-Mean-Squared-Error (RMSE) between the logarithm of the predicted value and the logarithm of the observed sales price.</p>
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# <p>業績:司機平均每小時營收；假設1:減少司機空車時間可提升業績、假設2:減少司機去接客人的路徑距離可提升業績。 (假設1應用於司機在尋找客人的情境下，什麼時間點應該往哪裡去比較會有客人；假設2應用於已知客人在某地點叫車，該派哪一個司機去路徑會比較短，但也要盡量平均分配每一個司機的業務量，避免部分司機因業績過差而離職。)</p>
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# <p>a. 收集每一個司機每一個時點的所在位址以及載客狀況(有無客人)以及客人上車地點、目的地。(此資料可由GPS收集) </p><p>b. 司機的營業收入</p>
# 3. 蒐集而來的資料型態為何
# <p>收集回來時為結構性資料以表格呈現欄位有:司機ID、日期、時間、經緯度、是否載客；另外一表格則記錄客戶相關資料，欄位有:客戶編號、上車日期時間、上車地點、下車日期時間、下車地點、營業收入。</p>
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# <p>a. 要往哪開才比較會載到客戶?(評估方式:檢視司機依照建議開車的平均空車時間是否顯著低於未依建議開)</p>
# <p>b. 誰去載客戶會比較好?(評估方式:檢視司機每小時營收的第一四分位數是否升高)</p>
